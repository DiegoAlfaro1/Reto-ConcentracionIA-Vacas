# %%
from util.load_dataframes import load_dataframe_vacas, load_dataframe_patadas, load_dataframe_inventario, load_dataframe_reporte

load_dataframe_vacas('datos/registros_sesiones_merged.csv')
# Out:
#           ID                    Main          ... Producciones (kg)                         Misc
#      ID Vaca          Hora de inicio  Acción  ...                TI    TD Razón de la desviación
# 0       1204  02/03/2025 02:24 a. m.  Ordeño  ...              1.15  3.15                    NaN
# 1       1204  02/03/2025 07:51 p. m.  Ordeño  ...              3.10  6.94                    NaN
# 2       1204  03/03/2025 06:00 a. m.  Ordeño  ...              1.44  3.05                    NaN
# 3       1204  04/03/2025 12:16 a. m.  Ordeño  ...              3.58  7.90                    NaN
# 4       1204  04/03/2025 06:27 p. m.  Ordeño  ...              3.47  7.67                    NaN
# ...      ...                     ...     ...  ...               ...   ...                    ...
# 7232    8794  15/07/2025 07:22 p. m.  Ordeño  ...              2.49  3.10                    NaN
# 7233    8794  16/07/2025 02:31 p. m.  Ordeño  ...              3.81  4.80                    NaN
# 7234    8794  17/07/2025 02:30 a. m.  Ordeño  ...              2.91  3.37                    NaN
# 7235    8794  17/07/2025 02:18 p. m.  Ordeño  ...              2.93  3.47                    NaN
# 7236    8794  18/07/2025 04:01 a. m.  Ordeño  ...              3.53  3.99                    NaN
#
# [7237 rows x 34 columns]

# %%
from util.load_dataframe import load_dataframe

load_dataframe('datos/registros_sesiones_merged.csv')
# Out:
#           ID                    Main                                           \
#      ID Vaca          Hora de inicio  Acción Duración (mm:ss) Producción (kg)
# 0       1204  02/03/2025 02:24 a. m.  Ordeño            07:23           11.13
# 1       1204  02/03/2025 07:51 p. m.  Ordeño            08:29           20.64
# 2       1204  03/03/2025 06:00 a. m.  Ordeño            05:05            9.59
# 3       1204  04/03/2025 12:16 a. m.  Ordeño            09:07           22.58
# 4       1204  04/03/2025 06:27 p. m.  Ordeño            12:09           22.71
# ...      ...                     ...     ...              ...             ...
# 7232    8794  15/07/2025 07:22 p. m.  Ordeño            07:14           10.17
# 7233    8794  16/07/2025 02:31 p. m.  Ordeño            06:57           15.63
# 7234    8794  17/07/2025 02:30 a. m.  Ordeño            05:44           11.23
# 7235    8794  17/07/2025 02:18 p. m.  Ordeño            05:32           11.65
# ...
